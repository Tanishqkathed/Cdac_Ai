# %% [markdown]
# #### Question 1

# %%
nums = [int(i) for i in input("enter number you want sum of").split(",")]
sum_num = 0 
j = 0
while j < len(nums):
    sum_num += nums[j]
    j += 1
print(sum_num)
# Out:
# enter number you want sum of 1,4,5,6,3,2
# 21

# %% [markdown]
# #### QUESTION 2

# %%
nums = [int(i) for i in input("You will get largest num").split(",") ]
max_num = [0]
j=1
for i in nums [1:]:
    if i > nums[j] :
        max_num = i
        j += 1
print("Largest:", max_num)
# Out:
# You will get largest num 1,2,3
# Largest: 3

# %% [markdown]
# #### QUESTION 3

# %%
nums = [int(i) for i in input("You will get samallest num").split(",") ]
min_num = [0]
j=1
for i in nums [:1]:
    if i < nums[j] :
        max_num = i
        j += 1
print("Smallest:", max_num)
# Out:
# You will get samallest num 1,2,3
# Smallest: 1

# %% [markdown]
# #### QUESTION 4

# %%
color_list = ["red","green","white","black"]
print(color_list[:1] , color_list[3:])
# Out:
# ['red'] ['black']

# %% [markdown]
# #### QUESTION 5

# %%
nums = [int(i) for i in input("You will get samallest num").split(",") ]
min_num = [0]
max_num = [0]
j=1
for i in nums [:1]:
    if i < nums[j] :
        min_num = i
        j += 1
k=1
for i in nums [1:]:
    if i > nums[k] :
        max_num = i
        k += 1        
print("Smallest:", min_num)
print("Largest:", max_num)


# nums = [int(i) for i in input("You will get samallest num").split(",") ]
# Out:
# You will get samallest num 1,2,3,4,5
# Smallest: 1
# Largest: 5

# %% [markdown]
# #### QUESTION 6

# %%
#6: write a Program to check if a string is palindrome or not

str1 = input("Write a string to check weather palindrome or not")
rev = str1[::-1]
if str1 == rev :
    print (" string is palindrome")

else :
     print (" string is not palindrome")
# Out:
# Write a string to check weather palindrome or not madam
#  string is palindrome

# %% [markdown]
# QUESTION 7

# %%
list1 = ["a", "b", ["c", ["d", "e", ["f", "g"], "k"], "l"], "m", "n"]
sub_list  = ["h", "i", "j"]

list1[2][1][2].extend(sub_list)
list1
# Out:
# ['a', 'b', ['c', ['d', 'e', ['f', 'g', 'h', 'i', 'j'], 'k'], 'l'], 'm', 'n']

# %% [markdown]
# QUESTION 8

# %%
list_int = (input("Enther the list ").split(","))
list_int[list_int.index("20")] = "200"
print(list_int)
# Out:
# Enther the list  123,23,20,20,20
# ['123', '23', '200', '20', '20']

# %% [markdown]
#  QUESTION 9

# %%
n = int(input("Wrote?"))
for i in range (0,n,5):
    if i%10==0:
        i = -i
    else:
        i = i
    print(i)
# Out:
# Wrote? 84
# 0
# 5
# -10
# 15
# -20
# 25
# -30
# 35
# -40
# 45
# -50
# 55
# -60
# 65
# -70
# 75
# -80

# %% [markdown]
# QUESTION 10

# %%
x = 0
n = int (input(""))
for i in range(1,n+1):
    x = 1/(i**3)
print(x)
# Out:
#  8
# 0.001953125

# %% [markdown]
# QUESTION 11

# %%
num =  [int(i) for i in input("Write nums you want sum of -: ").split(",") ] 

total = 0 
for x in num :
    total += x
print(total)
# Out:
# Write nums you want sum of -:  10,20,30
# 60

# %% [markdown]
# QUESTION 12

# %%
for i in range(65,90+1):
    
    val = chr(i)
    print(i ," = ", val)
# Out:
# 65  =  A
# 66  =  B
# 67  =  C
# 68  =  D
# 69  =  E
# 70  =  F
# 71  =  G
# 72  =  H
# 73  =  I
# 74  =  J
# 75  =  K
# 76  =  L
# 77  =  M
# 78  =  N
# 79  =  O
# 80  =  P
# 81  =  Q
# 82  =  R
# 83  =  S
# 84  =  T
# 85  =  U
# 86  =  V
# 87  =  W
# 88  =  X
# 89  =  Y
# 90  =  Z

# %% [markdown]
# QUESTION 13

# %%
for i in range (48,57+1):
    val = chr(i)
    print(i ," = ", val)
# Out:
# 48  =  0
# 49  =  1
# 50  =  2
# 51  =  3
# 52  =  4
# 53  =  5
# 54  =  6
# 55  =  7
# 56  =  8
# 57  =  9

# %% [markdown]
# QUESTION 14

# %%
for i in range (97,120+1):
    val = chr(i)
    print(i ," = ", val)
# Out:
# 97  =  a
# 98  =  b
# 99  =  c
# 100  =  d
# 101  =  e
# 102  =  f
# 103  =  g
# 104  =  h
# 105  =  i
# 106  =  j
# 107  =  k
# 108  =  l
# 109  =  m
# 110  =  n
# 111  =  o
# 112  =  p
# 113  =  q
# 114  =  r
# 115  =  s
# 116  =  t
# 117  =  u
# 118  =  v
# 119  =  w
# 120  =  x

# %% [markdown]
# QUESTION 15

# %%
List1 = [1, 2, 3, 4, 5, 6, 7]
a=[]
for i in List1 :
    List1 = [i**2]
    print(List1)
# Out:
# [1]
# [4]
# [9]
# [16]
# [25]
# [36]
# [49]

# %% [markdown]
# QUESTION 16

# %%
# f = input("Write string you want to sort  -: ")
# k = f.split()
# print(k.sort())

f = input("Write string you want to sort -: ")
k = f.split() 
k.sort()       
print(k)  
# print(k.sort()) return none cuz - The sort() method sorts the list in-place (it modifies k directly) but returns None
# Out:
# Write string you want to sort  -:  qwe werwer asf bwrf
# None
# Write string you want to sort -:  dsvds dvdv rwgwe
# ['dsvds', 'dvdv', 'rwgwe']

# %% [markdown]
# QUESTION 17

# %%
user_str = input ("Your input ")
translator = str.maketrans('', '', string.punctuation)
# """( ex  -
# table = str.maketrans("a", "A")  # "Change lowercase a to uppercase A"
# "cat".translate(table)  # "cAt") )'""" # // It creates a secret map telling Python: "Change A to X, B to Y, etc." You use this map with translate() to fix text instantly.
clean_string = user_str.translate(translator) # translate reads your text and applies that map everywhere

print("Updated" , clean_string)
# Out:
# Your input  hello's ! how are you! doing'
# Updated hellos  how are you doing

# %% [markdown]
# QUESTION 18

# %%
# smis_msg = int(input (""" \n 
# --- Student Managment Information System (SMIS) ---
# 1. Enter makes of 5 major subjects 
# 2. Calculate Total and Perenctage 
# 3. Determine Grade
# 4. Exit
# """))
# print(smis_msg)
# sub_1,sub_2,sub_3,sub_4,sub_5 = 0,0,0,0,0
# subjects =[sub_1,sub_2,sub_3,sub_4,sub_5] 
# if smis_msg == 1 :
#     subjects[0] = int(input("Enter marks for Subject 1"))
#     subjects[1] = int(input("Enter marks for Subject 2"))
#     subjects[2] = int(input("Enter marks for Subject 3"))
#     subjects[3] = int(input("Enter marks for Subject 4"))
#     subjects[4] = int(input("Enter marks for Subject 5"))
#     print ("Marks Recorded succesfully", (subjects))   
# total_marks = 0
# if smis_msg == 2 :
#     total_marks = sum(subjects)
#     print ("Your toal marks :", total_marks)
#     percentage = total_marks/5
#     print("Your Percentage  = " , percentage ,"%")
# grade = 0 
# elif smis_msg == 3 :
#     if  percentage == 0 :
#         print("NO marks found . Please selecet option 1 first")
        


        
#     if percentage > 85 :
#         grade = "A"
#         print("Calculated grade :" , grade)
#     elif percentage < 85 or percentage => 75 :
#         grade = "B"
#         print("Calculated grade :" , grade)
#     elif percentage < 75 or percentage => 50 :
#         grade = "C"
#         print("Calculated grade :" , grade)        
#     elif percentage > 30 or percentage =< 50 :
#         grade = "D"
#         print("Calculated grade :" , grade)      
#     elif percentage < 30 :
#         print("You need to attempt for Reappear " , grade)

# if smis_msg == 4 :
#     break
# Out:
#   Cell In[1], line 25
#     elif smis_msg == 3 :
#     ^
# SyntaxError: invalid syntax

# %%
subjects = [0,0,0,0,0]
percentage = 0
while True :
            smis_msg = int(input (""" \n 
            --- Student Managment Information System (SMIS) ---
            1. Enter makes of 5 major subjects 
            2. Calculate Total and Perenctage 
            3. Determine Grade
            4. Exit
            """))
            print(smis_msg)

            if smis_msg == 1 :
                    subjects[0] = int(input("Enter marks for Subject 1"))
                    subjects[1] = int(input("Enter marks for Subject 2"))
                    subjects[2] = int(input("Enter marks for Subject 3"))
                    subjects[3] = int(input("Enter marks for Subject 4"))
                    subjects[4] = int(input("Enter marks for Subject 5"))
                    print ("Marks Recorded succesfully", (subjects))   
                    
            elif smis_msg == 2 :
                    total_marks = sum(subjects)
                    print ("Your toal marks :", total_marks)
                    percentage = total_marks/5
                    print("Your Percentage  = " , percentage ,"%")

            elif smis_msg == 3 :
                    if  percentage == 0 :
                        print("NO marks found . Please selecet option 1 first")

                    else :
                        if percentage > 85:    
                            grade = "A"
                            print("Calculated grade :" , grade)
                        elif percentage <= 85 or percentage >= 75 :
                            grade = "B"
                            print("Calculated grade :" , grade)
                        elif percentage <= 75 or percentage >= 50 :
                            grade = "C"
                            print("Calculated grade :" , grade)        
                        elif percentage >= 30 or percentage <= 50 :
                            grade = "D"
                            print("Calculated grade :" , grade)      
                        elif percentage < 30 :
                            print("You need to attempt for Reappear " , grade)

            else :
                break
# Out:
#
#
#             --- Student Managment Information System (SMIS) ---
#             1. Enter makes of 5 major subjects
#             2. Calculate Total and Perenctage
#             3. Determine Grade
#             4. Exit
#              1
# 1
# Enter marks for Subject 1 78
# Enter marks for Subject 2 89
# Enter marks for Subject 3 67
# Enter marks for Subject 4 89
# Enter marks for Subject 5 90
# Marks Recorded succesfully [78, 89, 67, 89, 90]
#
#
#             --- Student Managment Information System (SMIS) ---
#             1. Enter makes of 5 major subjects
#             2. Calculate Total and Perenctage
#             3. Determine Grade
#             4. Exit
#              2
# 2
# Your toal marks : 413
# Your Percentage  =  82.6 %
#
#
#             --- Student Managment Information System (SMIS) ---
#             1. Enter makes of 5 major subjects
#             2. Calculate Total and Perenctage
#             3. Determine Grade
#             4. Exit
#              3
# 3
# ...

# %% [markdown]
# #### QUESTION 19

# %%
for i in range (1,4):
    for j in range (i,0,-1):
        print(j , end =  ' ' )

    print()
# Out:
# 1
# 2 1
# 3 2 1

# %% [markdown]
# ##### QUESTION 20
