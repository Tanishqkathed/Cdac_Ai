# %% [markdown]
# ## ASSIGNMENT 2

# %% [markdown]
# #### QUESTION 1

# %%
print(f" '\"hello\"'")
# Out:
#  '"hello"'

# %% [markdown]
# #### QUESTION 2

# %%
print(""" \""" " ' hello' " \""" """)
# Out:
#  """ " ' hello' " """

# %% [markdown]
# #### QUESTION 3

# %%
int_represent = input("?").split(",")
for i in int_represent:
    
    print(ord(i))
# Out:
# ? q,w,r
# 113
# 119
# 114

# %% [markdown]
# #### QUESTION 4

# %%
abc = ("abc") * 5 
print(abc)
# Out:
# abcabcabcabcabc

# %% [markdown]
# #### QUESTION 5

# %%
print("-"*50)
# Out:
# --------------------------------------------------

# %% [markdown]
# #### QUESTION 6

# %%
string = "Hello , how are you ?"
print(string.upper())
# Out:
# HELLO , HOW ARE YOU ?

# %% [markdown]
# #### QUESTION 7

# %%
string = input("write string")
print(string[:2] ,string[3:])
# Out:
# write string hello
# he lo

# %% [markdown]
# #### QUESTION 8

# %%
string = input("write string")
first_string= string[0]
final_result=first_string+string[1:].replace(first_string,"$")
final_result
# Out:
# write string helloh
# 'hello$ '

# %% [markdown]
# #### QUESITON 9

# %%
str_1 = input("write string")
str_2 = input("write string")
X = str_2[0] + str_1[1:]
Y = str_1[0]+ str_2[1:]
print(X, Y)
# Out:
# write string hello
# write string zow?
# zello  how?

# %% [markdown]
# #### QUESTION 10

# %%
str_1 = "ing"
str_2 = "ly"
string_1 = input("write string")
if string_1[-3:]== "ing":
    print(string_1[-3:].replace("ing","ly"))
else :
    print(string_1 + "ing")
# Out:
# write string hello
# helloing

# %% [markdown]
# #### QUESTION11

# %%
sub_1 =  input("write sub 1")
sub_2 =  input("write sub 2")
sub_3 =  input("write sub 3")
sub_4 =  input("write sub 4")
sub_5  =  input("write sub 5")
result = (int(sub_1) +int(sub_2)+int(sub_3)+int(sub_4)+int(sub_5)) / 5
if result <= 60 :
    print("first div" , result)
elif result >= 50 or  result <= 59: 
    print("Sec div" , result)
elif result >= 40 or  result <= 49: 
    print("Sec div" , result)
elif  result < 40:
    print("fail" , result)
# Out:
# write sub 1 10
# write sub 2 50
# write sub 3 30
# write sub 4 70
# write sub 5 90
# first div 50.0

# %% [markdown]
# #### QUESTION 12

# %%
num1 = input("")
num2= input("")
num3= input("")
largest = max(num1, num2, num3)
print (largest)
# Out:
#  1
#  2
#  3
# 3

# %% [markdown]
# #### QUESTION 13

# %%
year = int(input("Enter a year: "))
is_leap = (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)
if is_leap:
    print(f"{year}  leap ")
else:
    print(f"{year} not a leap")
# Out:
# Enter a year:  2021
# 2021 not a leap
